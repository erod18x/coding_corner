# %%
import requests
from bs4 import BeautifulSoup

#url = 'https://www.bloomberg.com/quote/INDU:IND/members'
url = 'https://www.google.com/search?q=dowjones&rlz=1C1JZAP_enUS809US809&oq=dowjones&aqs=chrome..69i57j0l5.5960j0j7&sourceid=chrome&ie=UTF-8'
source = requests.get(url).text
soup = BeautifulSoup(source,'lxml')

#print(soup)

dow = soup.find('span',class_='IsqQVc NprOob idfBrI6hAeAE-zJFzKq8ukm8')
print(dow)

links = soup.find_all('a')

for link in links:
    print(link.text)

#print(soup.prettify())

#print(soup.find_all('span', attrs = {'class':'IsqQVc NprOob i3nvLNZaeZKw-zJFzKq8ukm8'}))
# Out:
# None
# here
# Images
# Maps
# Play
# YouTube
# News
# Gmail
# Drive
# More »
# Web History
# Settings
# Sign in
#
# Images
# Videos
# News
# Shopping
# Maps
# Books
# Past hour
# Past 24 hours
# Past week
# Past month
# Past year
# Verbatim
# .DJI
#
# Disclaimer
# Google Finance
# Yahoo Finance
# MSN Money
# DailyFinance
# CNN Money
# News for dowjones
#
# Dow Jones Futures: Dow Stocks Microsoft, McDonald's, Verizon, Intel Teach Bear Market Lesson
# Dow Suffers Record-Breaking Christmas Eve Losses
# Dow Jones in Bear Market Territory, Why White House Failed to Ease Investors
# Dow Jones – Business & Financial News, Analysis & Insight
# Cached
# Similar
# ^DJI : Summary for Dow Jones Industrial Average - Yahoo Finance
# Cached
# DJIA - Dow Jones Industrial Average - MarketWatch
# .DJI: Dow Jones Industrial Average - Stock Quote and News - CNBC
# Cached
# Dow Jones Industrial Average - Wikipedia
# Cached
# Similar
# Dow 30 Companies - CNNMoney - Business - CNN.com
# Cached
# ...
